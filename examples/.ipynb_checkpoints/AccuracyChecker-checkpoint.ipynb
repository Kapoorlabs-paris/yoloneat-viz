# %%
import sys
import os
import glob
sys.path.append("../")
from yoloneatviz import HolovizNapari
import os
from pathlib import Path
import pandas as pd
import matplotlib.pyplot  as plt
from natsort import natsorted
import numpy as np

# %%
thresholdspace = 60
thresholdtime = 4
thresholdscore = 0.9
MovieName = []
NetworkName = []
CellName = []
Accuracy = []
FNAccuracy = []
FPAccuracy = []
resultsdir = '/content/drive/My Drive/Datasets/CAPED/Cherry/Results/'
Path(resultsdir).mkdir(exist_ok=True)

csv_gt = '/content/drive/My Drive/Datasets/CAPED/Cherry/CAPEDDivisionH2BmCherry_timelapse_60h.csv'

csv_pred = '/content/drive/My Drive/Datasets/CAPED/Cherry/Detection_d11_th2_iou0.2/DivisionLocationH2BmCherry_timelapse_60h.csv'
Name = os.path.basename(os.path.splitext(csv_pred)[0])
tp, fn, fp = HolovizNapari.TruePositives(csv_gt, csv_pred, thresholdspace = thresholdspace, thresholdtime = thresholdtime)
 
MovieName.append(Name)
NetworkName.append('d11_th2_iou0.2')
CellName.append('Division')
print(tp, fn, fp)
Accuracy.append(('%.4f'%tp))
FNAccuracy.append(('%.4f'%fn))
FPAccuracy.append(('%.4f'%fp))

csv_pred = '/content/drive/My Drive/Datasets/CAPED/Cherry/Detection_d11_th2_iou0.4/DivisionLocationH2BmCherry_timelapse_60h.csv'
Name = os.path.basename(os.path.splitext(csv_pred)[0])
tp, fn, fp = HolovizNapari.TruePositives(csv_gt, csv_pred, thresholdscore = thresholdscore, thresholdspace = thresholdspace, thresholdtime = thresholdtime)
MovieName.append(Name)
NetworkName.append('_2_0.4')
CellName.append('Division')
print(tp, fn, fp)
Accuracy.append(('%.4f'%tp))
FNAccuracy.append(('%.4f'%fn))
FPAccuracy.append(('%.4f'%fp))

csv_pred = '/content/drive/My Drive/Datasets/CAPED/Cherry/Detection_d11_th2_iou0.6/DivisionLocationH2BmCherry_timelapse_60h.csv'
Name = os.path.basename(os.path.splitext(csv_pred)[0])
tp, fn, fp = HolovizNapari.TruePositives(csv_gt, csv_pred,thresholdscore = thresholdscore, thresholdspace = thresholdspace, thresholdtime = thresholdtime)
MovieName.append(Name)
NetworkName.append('_2_0.6')
CellName.append('Division')
print(tp, fn, fp)
Accuracy.append(('%.4f'%tp))
FNAccuracy.append(('%.4f'%fn))
FPAccuracy.append(('%.4f'%fp))

csv_pred = '/content/drive/My Drive/Datasets/CAPED/Cherry/Detection_d11_th4_iou0.2/DivisionLocationH2BmCherry_timelapse_60h.csv'
Name = os.path.basename(os.path.splitext(csv_pred)[0])
tp, fn, fp = HolovizNapari.TruePositives(csv_gt, csv_pred,thresholdscore = thresholdscore, thresholdspace = thresholdspace, thresholdtime = thresholdtime)
 
MovieName.append(Name)
NetworkName.append('_4_0.2')
CellName.append('Division')
print(tp, fn, fp)
Accuracy.append(('%.4f'%tp))
FNAccuracy.append(('%.4f'%fn))
FPAccuracy.append(('%.4f'%fp))

csv_pred = '/content/drive/My Drive/Datasets/CAPED/Cherry/Detection_d11_th4_iou0.4/DivisionLocationH2BmCherry_timelapse_60h.csv'
Name = os.path.basename(os.path.splitext(csv_pred)[0])
tp, fn, fp = HolovizNapari.TruePositives(csv_gt, csv_pred,thresholdscore = thresholdscore, thresholdspace = thresholdspace, thresholdtime = thresholdtime)
MovieName.append(Name)
NetworkName.append('_4_0.4')
CellName.append('Division')
print(tp, fn, fp)
Accuracy.append(('%.4f'%tp))
FNAccuracy.append(('%.4f'%fn))
FPAccuracy.append(('%.4f'%fp))

csv_pred = '/content/drive/My Drive/Datasets/CAPED/Cherry/Detection_d11_th4_iou0.6/DivisionLocationH2BmCherry_timelapse_60h.csv'
Name = os.path.basename(os.path.splitext(csv_pred)[0])
tp, fn, fp = HolovizNapari.TruePositives(csv_gt, csv_pred,thresholdscore = thresholdscore, thresholdspace = thresholdspace, thresholdtime = thresholdtime)
MovieName.append(Name)
NetworkName.append('_4_0.6')
CellName.append('Division')
print(tp, fn, fp)
Accuracy.append(('%.4f'%tp))
FNAccuracy.append(('%.4f'%fn))
FPAccuracy.append(('%.4f'%fp))

df = pd.DataFrame(list(zip(MovieName,NetworkName,CellName,Accuracy)), index = None, 
                                                                      columns =['MovieName', 'NetworkName', 'CellType',  'Accuracy'])
                        
df.to_csv(resultsdir + '/' + 'DetectionAccuracy_d11' +  '.csv')  
df



colors = np.random.rand(len(Accuracy))
plt.scatter(NetworkName, list(map(float, Accuracy)),  alpha=0.5, c = colors)
plt.title("True Positive",fontsize=15)
plt.savefig(resultsdir + '/' + 'Detection_TP_d11' + '.png', dpi = 300)
plt.show()

plt.scatter(NetworkName, list(map(float, FNAccuracy)),  alpha=0.5, c = colors)
plt.title("False Negatives",fontsize=15)
plt.savefig(resultsdir + '/' + 'Detection_FN_d11' + '.png', dpi = 300)
plt.show()

plt.scatter(NetworkName, list(map(float, FPAccuracy)),  alpha=0.5, c = colors)
plt.title("False Positive",fontsize=15)
plt.savefig(resultsdir + '/' + 'Detection_FP_d11' + '.png', dpi = 300)
plt.show()


df

# %%
MovieName = []
NetworkName = []
CellName = []
Accuracy = []
resultsdir = '/content/drive/My Drive/Datasets/CAPED/Cherry/Results/'
Path(resultsdir).mkdir(exist_ok=True)

csv_gt = '/content/drive/My Drive/Datasets/CAPED/Cherry/CAPEDDivisionH2BmCherry_timelapse_60h.csv'

csv_pred = '/content/drive/My Drive/Datasets/CAPED/Cherry/Detection_d29_th2_iou0.2/DivisionLocationH2BmCherry_timelapse_60h.csv'
Name = os.path.basename(os.path.splitext(csv_pred)[0])
tp, fn, fp = HolovizNapari.TruePositives(csv_gt, csv_pred,thresholdscore = thresholdscore, thresholdspace = thresholdspace, thresholdtime = thresholdtime)
 
MovieName.append(Name)
NetworkName.append('Detection_d11_th2_iou0.2')
CellName.append('Division')
print(tp, fn, fp)
Accuracy.append(str('%.4f'%tp))


csv_pred = '/content/drive/My Drive/Datasets/CAPED/Cherry/Detection_d29_th2_iou0.4/DivisionLocationH2BmCherry_timelapse_60h.csv'
Name = os.path.basename(os.path.splitext(csv_pred)[0])
tp, fn, fp = HolovizNapari.TruePositives(csv_gt, csv_pred,thresholdscore = thresholdscore, thresholdspace = thresholdspace, thresholdtime = thresholdtime)
MovieName.append(Name)
NetworkName.append('Detection_d11_th2_iou0.4')
CellName.append('Division')
print(tp, fn, fp)
Accuracy.append(str('%.4f'%tp))

csv_pred = '/content/drive/My Drive/Datasets/CAPED/Cherry/Detection_d29_th2_iou0.6/DivisionLocationH2BmCherry_timelapse_60h.csv'
Name = os.path.basename(os.path.splitext(csv_pred)[0])
tp, fn, fp = HolovizNapari.TruePositives(csv_gt, csv_pred,thresholdscore = thresholdscore, thresholdspace = thresholdspace, thresholdtime = thresholdtime)
MovieName.append(Name)
NetworkName.append('Detection_d11_th2_iou0.6')
CellName.append('Division')
print(tp, fn, fp)
Accuracy.append(str('%.4f'%tp))

csv_pred = '/content/drive/My Drive/Datasets/CAPED/Cherry/Detection_d29_th4_iou0.2/DivisionLocationH2BmCherry_timelapse_60h.csv'
Name = os.path.basename(os.path.splitext(csv_pred)[0])
tp, fn, fp = HolovizNapari.TruePositives(csv_gt, csv_pred,thresholdscore = thresholdscore, thresholdspace = thresholdspace, thresholdtime = thresholdtime)
 
MovieName.append(Name)
NetworkName.append('Detection_d11_th4_iou0.2')
CellName.append('Division')
print(tp, fn, fp)
Accuracy.append(str('%.4f'%tp))


csv_pred = '/content/drive/My Drive/Datasets/CAPED/Cherry/Detection_d29_th4_iou0.4/DivisionLocationH2BmCherry_timelapse_60h.csv'
Name = os.path.basename(os.path.splitext(csv_pred)[0])
tp, fn, fp = HolovizNapari.TruePositives(csv_gt, csv_pred,thresholdscore = thresholdscore, thresholdspace = thresholdspace, thresholdtime = thresholdtime)
MovieName.append(Name)
NetworkName.append('Detection_d11_th4_iou0.4')
CellName.append('Division')
print(tp, fn, fp)
Accuracy.append(str('%.4f'%tp))

csv_pred = '/content/drive/My Drive/Datasets/CAPED/Cherry/Detection_d29_th4_iou0.6/DivisionLocationH2BmCherry_timelapse_60h.csv'
Name = os.path.basename(os.path.splitext(csv_pred)[0])
tp, fn, fp = HolovizNapari.TruePositives(csv_gt, csv_pred,thresholdscore = thresholdscore, thresholdspace = thresholdspace, thresholdtime = thresholdtime)
MovieName.append(Name)
NetworkName.append('Detection_d11_th4_iou0.6')
CellName.append('Division')
print(tp, fn, fp)
Accuracy.append(str('%.4f'%tp))

df = pd.DataFrame(list(zip(MovieName,NetworkName,CellName,Accuracy)), index = None, 
                                                                      columns =['MovieName', 'NetworkName', 'CellType',  'Accuracy'])
                        
df.to_csv(resultsdir + '/' + 'DetectionAccuracy_d29' +  '.csv')  
df

colors = np.random.rand(len(Accuracy))
plt.scatter(NetworkName, list(map(float, Accuracy)),  alpha=0.5, c = colors)
plt.title("True Positive",fontsize=15)
plt.savefig(resultsdir + '/' + 'Detection_TP_d29' + '.png', dpi = 300)
plt.show()

plt.scatter(NetworkName, list(map(float, FNAccuracy)),  alpha=0.5, c = colors)
plt.title("False Negatives",fontsize=15)
plt.savefig(resultsdir + '/' + 'Detection_FN_d29' + '.png', dpi = 300)
plt.show()

plt.scatter(NetworkName, list(map(float, FPAccuracy)),  alpha=0.5, c = colors)
plt.title("False Positive",fontsize=15)
plt.savefig(resultsdir + '/' + 'Detection_FP_d29' + '.png', dpi = 300)
plt.show()
df
