# %%
import sys
import os
import glob
sys.path.append("../")
from yoloneatviz import HolovizNapari
import os
from pathlib import Path
import pandas as pd
import matplotlib.pyplot  as plt
from natsort import natsorted
import numpy as np

# %% [markdown]
# Movie: DIAP_mov5Division

# %%
threshold = 20
MovieName = []
NetworkName = []
CellName = []
Accuracy = []
resultsdir = '/Users/aimachine/oneat_analysis/Penultimate/Results/'
Path(resultsdir).mkdir(exist_ok=True)

csv_gt = '/Users/aimachine/oneat_analysis/Penultimate/GT/divisionbin2V1/ONEATDIAP_mov5Division.csv'

csv_pred = '/Users/aimachine/oneat_analysis/Penultimate/Divd38resf16/DivisionLocationDIAP_mov5.csv'
Name = os.path.basename(os.path.splitext(csv_pred)[0])
tp = HolovizNapari.TruePositives(csv_gt, csv_pred, threshold = threshold)
MovieName.append(Name)
NetworkName.append('Divd38resf16')
CellName.append('Division')
Accuracy.append(str('%.4f'%tp))


csv_pred = '/Users/aimachine/oneat_analysis/Penultimate/Divd29resf32/DivisionLocationDIAP_mov5.csv'
Name = os.path.basename(os.path.splitext(csv_pred)[0])
tp = HolovizNapari.TruePositives(csv_gt, csv_pred, threshold = threshold)
MovieName.append(Name)
NetworkName.append('Divd29resf32')
CellName.append('Division')
Accuracy.append(str('%.4f'%tp))

csv_pred = '/Users/aimachine/oneat_analysis/Penultimate/Microd38f32/DivisionLocationDIAP_mov5.csv'
Name = os.path.basename(os.path.splitext(csv_pred)[0])
tp = HolovizNapari.TruePositives(csv_gt, csv_pred, threshold = threshold)
MovieName.append(Name)
NetworkName.append('Microd38f32')
CellName.append('Division')
Accuracy.append(str('%.4f'%tp))

csv_pred = '/Users/aimachine/oneat_analysis/Penultimate/Microd29f32/DivisionLocationDIAP_mov5.csv'
Name = os.path.basename(os.path.splitext(csv_pred)[0])
tp = HolovizNapari.TruePositives(csv_gt, csv_pred, threshold = threshold)
MovieName.append(Name)
NetworkName.append('Microd29f32')
CellName.append('Division')
Accuracy.append(str('%.4f'%tp))



csv_pred = '/Users/aimachine/oneat_analysis/Penultimate/Divd38resf16/DivisionLocationwt_N10.csv'
Name = os.path.basename(os.path.splitext(csv_pred)[0])
tp = HolovizNapari.TruePositives(csv_gt, csv_pred, threshold = threshold)
MovieName.append(Name)
NetworkName.append('Divd38resf16')
CellName.append('Division')
Accuracy.append(str('%.4f'%tp))


csv_pred = '/Users/aimachine/oneat_analysis/Penultimate/Divd29resf32/DivisionLocationwt_N10.csv'
Name = os.path.basename(os.path.splitext(csv_pred)[0])
tp = HolovizNapari.TruePositives(csv_gt, csv_pred, threshold = threshold)
MovieName.append(Name)
NetworkName.append('Divd29resf32')
CellName.append('Division')
Accuracy.append(str('%.4f'%tp))

csv_pred = '/Users/aimachine/oneat_analysis/Penultimate/Microd38f32/DivisionLocationwt_N10.csv'
Name = os.path.basename(os.path.splitext(csv_pred)[0])
tp = HolovizNapari.TruePositives(csv_gt, csv_pred, threshold = threshold)
MovieName.append(Name)
NetworkName.append('Microd38f32')
CellName.append('Division')
Accuracy.append(str('%.4f'%tp))

csv_pred = '/Users/aimachine/oneat_analysis/Penultimate/Microd29f32/DivisionLocationwt_N10.csv'
Name = os.path.basename(os.path.splitext(csv_pred)[0])
tp = HolovizNapari.TruePositives(csv_gt, csv_pred, threshold = threshold)
MovieName.append(Name)
NetworkName.append('Microd29f32')
CellName.append('Division')
Accuracy.append(str('%.4f'%tp))



csv_gt = '/Users/aimachine/oneat_analysis/Penultimate/GT/divisionbin2V1/ONEATTimeLapseBIG1Division.csv'

csv_pred = '/Users/aimachine/oneat_analysis/Penultimate/Divd38resf16/DivisionLocationTimeLapseBIG1.csv'
Name = os.path.basename(os.path.splitext(csv_pred)[0])
tp = HolovizNapari.TruePositives(csv_gt, csv_pred, threshold = threshold)
MovieName.append(Name)
NetworkName.append('Divd38resf16')
CellName.append('Division')
Accuracy.append(str('%.4f'%tp))


csv_pred = '/Users/aimachine/oneat_analysis/Penultimate/Divd29resf32/DivisionLocationTimeLapseBIG1.csv'
Name = os.path.basename(os.path.splitext(csv_pred)[0])
tp = HolovizNapari.TruePositives(csv_gt, csv_pred, threshold = threshold)
MovieName.append(Name)
NetworkName.append('Divd29resf32')
CellName.append('Division')
Accuracy.append(str('%.4f'%tp))

csv_pred = '/Users/aimachine/oneat_analysis/Penultimate/Microd38f32/DivisionLocationTimeLapseBIG1.csv'
Name = os.path.basename(os.path.splitext(csv_pred)[0])
tp = HolovizNapari.TruePositives(csv_gt, csv_pred, threshold = threshold)
MovieName.append(Name)
NetworkName.append('Microd38f32')
CellName.append('Division')
Accuracy.append(str('%.4f'%tp))

csv_pred = '/Users/aimachine/oneat_analysis/Penultimate/Microd29f32/DivisionLocationTimeLapseBIG1.csv'
Name = os.path.basename(os.path.splitext(csv_pred)[0])
tp = HolovizNapari.TruePositives(csv_gt, csv_pred, threshold = threshold)
MovieName.append(Name)
NetworkName.append('Microd29f32')
CellName.append('Division')
Accuracy.append(str('%.4f'%tp))





csv_gt = '/Users/aimachine/oneat_analysis/Penultimate/GT/divisionbin2V1/ONEATTimeLapseBIG5Division.csv'

csv_pred = '/Users/aimachine/oneat_analysis/Penultimate/Divd38resf16/DivisionLocationTimeLapseBIG5.csv'
Name = os.path.basename(os.path.splitext(csv_pred)[0])
tp = HolovizNapari.TruePositives(csv_gt, csv_pred, threshold = threshold)
MovieName.append(Name)
NetworkName.append('Divd38resf16')
CellName.append('Division')
Accuracy.append(str('%.4f'%tp))


csv_pred = '/Users/aimachine/oneat_analysis/Penultimate/Divd29resf32/DivisionLocationTimeLapseBIG5.csv'
Name = os.path.basename(os.path.splitext(csv_pred)[0])
tp = HolovizNapari.TruePositives(csv_gt, csv_pred, threshold = threshold)
MovieName.append(Name)
NetworkName.append('Divd29resf32')
CellName.append('Division')
Accuracy.append(str('%.4f'%tp))

csv_pred = '/Users/aimachine/oneat_analysis/Penultimate/Microd38f32/DivisionLocationTimeLapseBIG5.csv'
Name = os.path.basename(os.path.splitext(csv_pred)[0])
tp = HolovizNapari.TruePositives(csv_gt, csv_pred, threshold = threshold)
MovieName.append(Name)
NetworkName.append('Microd38f32')
CellName.append('Division')
Accuracy.append(str('%.4f'%tp))

csv_pred = '/Users/aimachine/oneat_analysis/Penultimate/Microd29f32/DivisionLocationTimeLapseBIG5.csv'
Name = os.path.basename(os.path.splitext(csv_pred)[0])
tp = HolovizNapari.TruePositives(csv_gt, csv_pred, threshold = threshold)
MovieName.append(Name)
NetworkName.append('Microd29f32')
CellName.append('Division')
Accuracy.append(str('%.4f'%tp))




csv_gt = '/Users/aimachine/oneat_analysis/Penultimate/GT/divisionbin2V1/ONEATEventMovieDivision.csv'

csv_pred = '/Users/aimachine/oneat_analysis/Penultimate/Divd38resf16/DivisionLocationEventMovie.csv'
Name = os.path.basename(os.path.splitext(csv_pred)[0])
tp = HolovizNapari.TruePositives(csv_gt, csv_pred, threshold = threshold)
MovieName.append(Name)
NetworkName.append('Divd38resf16')
CellName.append('Division')
Accuracy.append(str('%.4f'%tp))


csv_pred = '/Users/aimachine/oneat_analysis/Penultimate/Divd29resf32/DivisionLocationEventMovie.csv'
Name = os.path.basename(os.path.splitext(csv_pred)[0])
tp = HolovizNapari.TruePositives(csv_gt, csv_pred, threshold = threshold)
MovieName.append(Name)
NetworkName.append('Divd29resf32')
CellName.append('Division')
Accuracy.append(str('%.4f'%tp))

csv_pred = '/Users/aimachine/oneat_analysis/Penultimate/Microd38f32/DivisionLocationEventMovie.csv'
Name = os.path.basename(os.path.splitext(csv_pred)[0])
tp = HolovizNapari.TruePositives(csv_gt, csv_pred, threshold = threshold)
MovieName.append(Name)
NetworkName.append('Microd38f32')
CellName.append('Division')
Accuracy.append(str('%.4f'%tp))

csv_pred = '/Users/aimachine/oneat_analysis/Penultimate/Microd29f32/DivisionLocationEventMovie.csv'
Name = os.path.basename(os.path.splitext(csv_pred)[0])
tp = HolovizNapari.TruePositives(csv_gt, csv_pred, threshold = threshold)
MovieName.append(Name)
NetworkName.append('Microd29f32')
CellName.append('Division')
Accuracy.append(str('%.4f'%tp))



df = pd.DataFrame(list(zip(MovieName,NetworkName,CellName,Accuracy)), index = None, 
                                                                      columns =['MovieName', 'NetworkName', 'CellType',  'Accuracy'])
                        
df.to_csv(resultsdir + '/' + 'DivisionDynamicAccuracy' +  '.csv')  
df

Accuracy = natsorted(Accuracy, reverse = True)

colors = np.random.rand(len(Accuracy))
plt.scatter(NetworkName, Accuracy,  alpha=0.5, c = colors)


plt.savefig(resultsdir + '/' + 'FullDynamicaccuracy' + '.png', dpi = 300)
plt.show()
df
# Out:
#                         MovieName   NetworkName  CellType  Accuracy
# 0       DivisionLocationDIAP_mov5  Divd38resf16  Division  100.0000
# 1       DivisionLocationDIAP_mov5  Divd29resf32  Division  100.0000
# 2       DivisionLocationDIAP_mov5   Microd38f32  Division   89.5833
# 3       DivisionLocationDIAP_mov5   Microd29f32  Division   91.7468
# 4          DivisionLocationwt_N10  Divd38resf16  Division   58.8141
# 5          DivisionLocationwt_N10  Divd29resf32  Division   43.6699
# 6          DivisionLocationwt_N10   Microd38f32  Division   45.5929
# 7          DivisionLocationwt_N10   Microd29f32  Division   59.1346
# 8   DivisionLocationTimeLapseBIG1  Divd38resf16  Division   95.6989
# 9   DivisionLocationTimeLapseBIG1  Divd29resf32  Division   96.7742
# 10  DivisionLocationTimeLapseBIG1   Microd38f32  Division   93.5484
# 11  DivisionLocationTimeLapseBIG1   Microd29f32  Division   91.3978
# 12  DivisionLocationTimeLapseBIG5  Divd38resf16  Division  100.0000
# 13  DivisionLocationTimeLapseBIG5  Divd29resf32  Division  100.0000
# 14  DivisionLocationTimeLapseBIG5   Microd38f32  Division   99.6222
# 15  DivisionLocationTimeLapseBIG5   Microd29f32  Division   99.8741
# 16     DivisionLocationEventMovie  Divd38resf16  Division   99.7442
# 17     DivisionLocationEventMovie  Divd29resf32  Division   99.3222
# 18     DivisionLocationEventMovie   Microd38f32  Division   98.5420
# 19     DivisionLocationEventMovie   Microd29f32  Division   98.3502

# %%
threshold = 10
MovieName = []
NetworkName = []
CellName = []
Accuracy = []
csv_gt = '/Users/aimachine/oneat_analysis/Penultimate/GT/divisionbin2V1/ONEATDIAP_mov5Division.csv'
csv_pred = '/Users/aimachine/oneat_analysis/Penultimate/StaticSave29resf16/DivisionLocationDIAP_mov5.csv'
Name = os.path.basename(os.path.splitext(csv_pred)[0])
tp = HolovizNapari.TruePositives(csv_gt, csv_pred, threshold = threshold)
MovieName.append(Name)
NetworkName.append('Static29resf16')
CellName.append('Division')
Accuracy.append(str('%.4f'%tp))



csv_pred = '/Users/aimachine/oneat_analysis/Penultimate/StaticSave29resf32/DivisionLocationDIAP_mov5.csv'
Name = os.path.basename(os.path.splitext(csv_pred)[0])
tp = HolovizNapari.TruePositives(csv_gt, csv_pred, threshold = threshold)
MovieName.append(Name)
NetworkName.append('Static29resf32')
CellName.append('Division')
Accuracy.append(str('%.4f'%tp))


csv_gt = '/Users/aimachine/oneat_analysis/Penultimate/GT/divisionbin2V1/ONEATwt_N10Division.csv'

csv_pred = '/Users/aimachine/oneat_analysis/Penultimate/StaticSave29resf16/DivisionLocationwt_N10.csv'
Name = os.path.basename(os.path.splitext(csv_pred)[0])
tp = HolovizNapari.TruePositives(csv_gt, csv_pred, threshold = threshold)
MovieName.append(Name)
NetworkName.append('Static29resf16')
CellName.append('Division')
Accuracy.append(str('%.4f'%tp))

csv_pred = '/Users/aimachine/oneat_analysis/Penultimate/StaticSave38resf16/DivisionLocationwt_N10.csv'
Name = os.path.basename(os.path.splitext(csv_pred)[0])
tp = HolovizNapari.TruePositives(csv_gt, csv_pred, threshold = threshold)
MovieName.append(Name)
NetworkName.append('Static38resf16')
CellName.append('Division')
Accuracy.append(str('%.4f'%tp))

csv_pred = '/Users/aimachine/oneat_analysis/Penultimate/StaticSave29resf32/DivisionLocationwt_N10.csv'
Name = os.path.basename(os.path.splitext(csv_pred)[0])
tp = HolovizNapari.TruePositives(csv_gt, csv_pred, threshold = threshold)
MovieName.append(Name)
NetworkName.append('Static29resf32')
CellName.append('Division')
Accuracy.append(str('%.4f'%tp))

csv_gt = '/Users/aimachine/oneat_analysis/Penultimate/GT/divisionbin2V1/ONEATTimeLapseBIG1Division.csv'

csv_pred = '/Users/aimachine/oneat_analysis/Penultimate/StaticSave29resf16/DivisionLocationTimeLapseBIG1.csv'
Name = os.path.basename(os.path.splitext(csv_pred)[0])
tp = HolovizNapari.TruePositives(csv_gt, csv_pred, threshold = threshold)
MovieName.append(Name)
NetworkName.append('Static29resf16')
CellName.append('Division')
Accuracy.append(str('%.4f'%tp))

csv_pred = '/Users/aimachine/oneat_analysis/Penultimate/StaticSave38resf16/DivisionLocationTimeLapseBIG1.csv'
Name = os.path.basename(os.path.splitext(csv_pred)[0])
tp = HolovizNapari.TruePositives(csv_gt, csv_pred, threshold = threshold)
MovieName.append(Name)
NetworkName.append('Static38resf16')
CellName.append('Division')
Accuracy.append(str('%.4f'%tp))

csv_pred = '/Users/aimachine/oneat_analysis/Penultimate/StaticSave29resf32/DivisionLocationTimeLapseBIG1.csv'
Name = os.path.basename(os.path.splitext(csv_pred)[0])
tp = HolovizNapari.TruePositives(csv_gt, csv_pred, threshold = threshold)
MovieName.append(Name)
NetworkName.append('Static29resf32')
CellName.append('Division')
Accuracy.append(str('%.4f'%tp))

csv_gt = '/Users/aimachine/oneat_analysis/Penultimate/GT/divisionbin2V1/ONEATTimeLapseBIG5Division.csv'
csv_pred = '/Users/aimachine/oneat_analysis/Penultimate/StaticSave29resf16/DivisionLocationTimeLapseBIG5.csv'
Name = os.path.basename(os.path.splitext(csv_pred)[0])
tp = HolovizNapari.TruePositives(csv_gt, csv_pred, threshold = threshold)
MovieName.append(Name)
NetworkName.append('Static29resf16')
CellName.append('Division')
Accuracy.append(str('%.4f'%tp))

csv_pred = '/Users/aimachine/oneat_analysis/Penultimate/StaticSave38resf16/DivisionLocationTimeLapseBIG5.csv'
Name = os.path.basename(os.path.splitext(csv_pred)[0])
tp = HolovizNapari.TruePositives(csv_gt, csv_pred, threshold = threshold)
MovieName.append(Name)
NetworkName.append('Static38resf16')
CellName.append('Division')
Accuracy.append(str('%.4f'%tp))

csv_pred = '/Users/aimachine/oneat_analysis/Penultimate/StaticSave29resf32/DivisionLocationTimeLapseBIG5.csv'
Name = os.path.basename(os.path.splitext(csv_pred)[0])
tp = HolovizNapari.TruePositives(csv_gt, csv_pred, threshold = threshold)
MovieName.append(Name)
NetworkName.append('Static29resf32')
CellName.append('Division')
Accuracy.append(str('%.4f'%tp))


csv_gt = '/Users/aimachine/oneat_analysis/Penultimate/GT/divisionbin2V1/ONEATEventMovieDivision.csv'
csv_pred = '/Users/aimachine/oneat_analysis/Penultimate/StaticSave29resf16/DivisionLocationEventMovie.csv'
Name = os.path.basename(os.path.splitext(csv_pred)[0])
tp = HolovizNapari.TruePositives(csv_gt, csv_pred, threshold = threshold)
MovieName.append(Name)
NetworkName.append('Static29resf16')
CellName.append('Division')
Accuracy.append(str('%.4f'%tp))



csv_pred = '/Users/aimachine/oneat_analysis/Penultimate/StaticSave29resf32/DivisionLocationEventMovie.csv'
Name = os.path.basename(os.path.splitext(csv_pred)[0])
tp = HolovizNapari.TruePositives(csv_gt, csv_pred, threshold = threshold)
MovieName.append(Name)
NetworkName.append('Static29resf32')
CellName.append('Division')
Accuracy.append(str('%.4f'%tp))

csv_pred = '/Users/aimachine/oneat_analysis/Penultimate/StaticSave38resf16/DivisionLocationDIAP_mov5.csv'
Name = os.path.basename(os.path.splitext(csv_pred)[0])
tp = HolovizNapari.TruePositives(csv_gt, csv_pred, threshold = threshold)
MovieName.append(Name)
NetworkName.append('Static38resf16')
CellName.append('Division')
Accuracy.append(str('%.4f'%tp))

df = pd.DataFrame(list(zip(MovieName,NetworkName,CellName,Accuracy)), index = None, 
                                                                      columns =['MovieName', 'NetworkName', 'CellType',  'Accuracy'])
                        
df.to_csv(resultsdir + '/' + 'DivisionStaticAccuracy' +  '.csv')  
df
Accuracy = natsorted(Accuracy, reverse = True)

colors = np.random.rand(len(Accuracy))
plt.scatter(NetworkName, Accuracy, alpha=0.5, c = colors)

plt.show()
plt.savefig(resultsdir + '/' + 'DivisionStaticaccuracy' + '.png', dpi = 300)

# %% [markdown]
# Next

# %%
threshold = 20
MovieName = []
NetworkName = []
CellName = []
Accuracy = []
csv_gt = '/Users/aimachine/oneat_analysis/Penultimate/GT/divisionbin2V1/cellnetbin2/ONEATFlo_pupe1_s1_s2_s3_s4_movNonMatureP1.csv'

csv_pred = '/Users/aimachine/oneat_analysis/Penultimate/StaticSave29resf16/NonMatureP1LocationFlo_pupe1_s1_s2_s3_s4_mov.csv'
Name = os.path.basename(os.path.splitext(csv_pred)[0])
tp = HolovizNapari.TruePositives(csv_gt, csv_pred, threshold = threshold)
MovieName.append(Name)
NetworkName.append('StaticSave29resf16')
CellName.append('NonMature')
Accuracy.append(str('%.4f'%tp))

csv_pred = '/Users/aimachine/oneat_analysis/Penultimate/StaticSave29resf32/NonMatureP1LocationFlo_pupe1_s1_s2_s3_s4_mov.csv'
Name = os.path.basename(os.path.splitext(csv_pred)[0])
tp = HolovizNapari.TruePositives(csv_gt, csv_pred, threshold = threshold)
MovieName.append(Name)
NetworkName.append('StaticSave29resf32')
CellName.append('NonMature')
Accuracy.append(str('%.4f'%tp))

csv_pred = '/Users/aimachine/oneat_analysis/Penultimate/StaticSave38resf16/NonMatureP1LocationFlo_pupe1_s1_s2_s3_s4_mov.csv'
Name = os.path.basename(os.path.splitext(csv_pred)[0])
tp = HolovizNapari.TruePositives(csv_gt, csv_pred, threshold = threshold)
MovieName.append(Name)
NetworkName.append('StaticSave38resf16')
CellName.append('NonMature')
Accuracy.append(str('%.4f'%tp))

csv_gt = '/Users/aimachine/oneat_analysis/Penultimate/GT/divisionbin2V1/cellnetbin2/ONEATFlo_pupe2_mutant_s5_s6_s7_s8_movNonMatureP1.csv'

csv_pred = '/Users/aimachine/oneat_analysis/Penultimate/StaticSave29resf16/NonMatureP1LocationFlo_pupe2_mutant_s5_s6_s7_s8_mov.csv'
Name = os.path.basename(os.path.splitext(csv_pred)[0])
tp = HolovizNapari.TruePositives(csv_gt, csv_pred, threshold = threshold)
MovieName.append(Name)
NetworkName.append('StaticSave29resf16')
CellName.append('NonMature')
Accuracy.append(str('%.4f'%tp))

csv_pred = '/Users/aimachine/oneat_analysis/Penultimate/StaticSave29resf32/NonMatureP1LocationFlo_pupe2_mutant_s5_s6_s7_s8_mov.csv'
Name = os.path.basename(os.path.splitext(csv_pred)[0])
tp = HolovizNapari.TruePositives(csv_gt, csv_pred, threshold = threshold)
MovieName.append(Name)
NetworkName.append('StaticSave29resf32')
CellName.append('NonMature')
Accuracy.append(str('%.4f'%tp))

csv_pred = '/Users/aimachine/oneat_analysis/Penultimate/StaticSave38resf16/NonMatureP1LocationFlo_pupe2_mutant_s5_s6_s7_s8_mov.csv'
Name = os.path.basename(os.path.splitext(csv_pred)[0])
tp = HolovizNapari.TruePositives(csv_gt, csv_pred, threshold = threshold)
MovieName.append(Name)
NetworkName.append('StaticSave38resf16')
CellName.append('NonMature')
Accuracy.append(str('%.4f'%tp))

csv_gt = '/Users/aimachine/oneat_analysis/Penultimate/GT/divisionbin2V1/cellnetbin2/ONEATEventMovieNonMatureP1.csv'

csv_pred = '/Users/aimachine/oneat_analysis/Penultimate/StaticSave29resf16/NonMatureP1LocationEventMovie.csv'
Name = os.path.basename(os.path.splitext(csv_pred)[0])
tp = HolovizNapari.TruePositives(csv_gt, csv_pred, threshold = threshold)
MovieName.append(Name)
NetworkName.append('StaticSave29resf16')
CellName.append('NonMature')
Accuracy.append(str('%.4f'%tp))

csv_pred = '/Users/aimachine/oneat_analysis/Penultimate/StaticSave29resf32/NonMatureP1LocationEventMovie.csv'
Name = os.path.basename(os.path.splitext(csv_pred)[0])
tp = HolovizNapari.TruePositives(csv_gt, csv_pred, threshold = threshold)
MovieName.append(Name)
NetworkName.append('StaticSave29resf32')
CellName.append('NonMature')
Accuracy.append(str('%.4f'%tp))

csv_pred = '/Users/aimachine/oneat_analysis/Penultimate/StaticSave38resf16/NonMatureP1LocationEventMovie.csv'
Name = os.path.basename(os.path.splitext(csv_pred)[0])
tp = HolovizNapari.TruePositives(csv_gt, csv_pred, threshold = threshold)
MovieName.append(Name)
NetworkName.append('StaticSave38resf16')
CellName.append('NonMature')
Accuracy.append(str('%.4f'%tp))

csv_gt = '/Users/aimachine/oneat_analysis/Penultimate/GT/divisionbin2V1/cellnetbin2/ONEATTimeLapseBIG1NonMatureP1.csv'

csv_pred = '/Users/aimachine/oneat_analysis/Penultimate/StaticSave29resf16/NonMatureP1LocationTimeLapseBIG1.csv'
Name = os.path.basename(os.path.splitext(csv_pred)[0])
tp = HolovizNapari.TruePositives(csv_gt, csv_pred, threshold = threshold)
MovieName.append(Name)
NetworkName.append('StaticSave29resf16')
CellName.append('NonMature')
Accuracy.append(str('%.4f'%tp))

csv_pred = '/Users/aimachine/oneat_analysis/Penultimate/StaticSave29resf32/NonMatureP1LocationTimeLapseBIG1.csv'
Name = os.path.basename(os.path.splitext(csv_pred)[0])
tp = HolovizNapari.TruePositives(csv_gt, csv_pred, threshold = threshold)
MovieName.append(Name)
NetworkName.append('StaticSave29resf32')
CellName.append('NonMature')
Accuracy.append(str('%.4f'%tp))

csv_pred = '/Users/aimachine/oneat_analysis/Penultimate/StaticSave38resf16/NonMatureP1LocationTimeLapseBIG1.csv'
Name = os.path.basename(os.path.splitext(csv_pred)[0])
tp = HolovizNapari.TruePositives(csv_gt, csv_pred, threshold = threshold)
MovieName.append(Name)
NetworkName.append('StaticSave38resf16')
CellName.append('NonMature')
Accuracy.append(str('%.4f'%tp))



df = pd.DataFrame(list(zip(MovieName,NetworkName,CellName,Accuracy)), index = None, 
                                                                      columns =['MovieName', 'NetworkName', 'CellType',  'Accuracy'])
                        
df.to_csv(resultsdir + '/' + 'NonMatureP1cellsAccuracy' +  '.csv')  
df
Accuracy = natsorted(Accuracy, reverse = True)

colors = np.random.rand(len(Accuracy))
plt.scatter(NetworkName, Accuracy,alpha=0.5, c = colors)


plt.show()
plt.savefig(resultsdir + '/' + 'NonMatureP1Accuracy' + '.png', dpi = 300)
df
# Out:
#                                             MovieName         NetworkName  \
# 0        NonMatureP1LocationFlo_pupe1_s1_s2_s3_s4_mov  StaticSave29resf16
# 1        NonMatureP1LocationFlo_pupe1_s1_s2_s3_s4_mov  StaticSave29resf32
# 2        NonMatureP1LocationFlo_pupe1_s1_s2_s3_s4_mov  StaticSave38resf16
# 3   NonMatureP1LocationFlo_pupe2_mutant_s5_s6_s7_s...  StaticSave29resf16
# 4   NonMatureP1LocationFlo_pupe2_mutant_s5_s6_s7_s...  StaticSave29resf32
# 5   NonMatureP1LocationFlo_pupe2_mutant_s5_s6_s7_s...  StaticSave38resf16
# 6                       NonMatureP1LocationEventMovie  StaticSave29resf16
# 7                       NonMatureP1LocationEventMovie  StaticSave29resf32
# 8                       NonMatureP1LocationEventMovie  StaticSave38resf16
# 9                    NonMatureP1LocationTimeLapseBIG1  StaticSave29resf16
# 10                   NonMatureP1LocationTimeLapseBIG1  StaticSave29resf32
# 11                   NonMatureP1LocationTimeLapseBIG1  StaticSave38resf16
#
#      CellType Accuracy
# 0   NonMature  97.2973
# 1   NonMature  83.7838
# 2   NonMature   5.4054
# 3   NonMature  96.0526
# 4   NonMature  90.7895
# 5   NonMature  94.7368
# 6   NonMature  67.9245
# 7   NonMature  90.5660
# 8   NonMature  86.7925
# 9   NonMature  79.0323
# 10  NonMature  94.0860
# 11  NonMature  93.5484

# %%
csv_gt = '/Users/aimachine/oneat_analysis/Penultimate/GT/divisionbin2V1/cellnetbin2/ONEATFlo_pupe1_s1_s2_s3_s4_movMatureP1.csv'



csv_pred = '/Users/aimachine/oneat_analysis/Penultimate/StaticSave29resf16/MatureP1LocationFlo_pupe1_s1_s2_s3_s4_mov.csv'
Name = os.path.basename(os.path.splitext(csv_pred)[0])
tp = HolovizNapari.TruePositives(csv_gt, csv_pred, threshold = threshold)
MovieName.append(Name)
NetworkName.append('StaticSave29resf16')
CellName.append('Mature')
Accuracy.append(str('%.4f'%tp))

csv_pred = '/Users/aimachine/oneat_analysis/Penultimate/StaticSave29resf32/MatureP1LocationFlo_pupe1_s1_s2_s3_s4_mov.csv'
Name = os.path.basename(os.path.splitext(csv_pred)[0])
tp = HolovizNapari.TruePositives(csv_gt, csv_pred, threshold = threshold)
MovieName.append(Name)
NetworkName.append('StaticSave29resf32')
CellName.append('Mature')
Accuracy.append(str('%.4f'%tp))

csv_pred = '/Users/aimachine/oneat_analysis/Penultimate/StaticSave38resf16/MatureP1LocationFlo_pupe1_s1_s2_s3_s4_mov.csv'
Name = os.path.basename(os.path.splitext(csv_pred)[0])
tp = HolovizNapari.TruePositives(csv_gt, csv_pred, threshold = threshold)
MovieName.append(Name)
NetworkName.append('StaticSave38resf16')
CellName.append('Mature')
Accuracy.append(str('%.4f'%tp))



csv_gt = '/Users/aimachine/oneat_analysis/Penultimate/GT/divisionbin2V1/cellnetbin2/ONEATFlo_pupe2_mutant_s5_s6_s7_s8_movMatureP1.csv'



csv_pred = '/Users/aimachine/oneat_analysis/Penultimate/StaticSave29resf16/MatureP1LocationFlo_pupe2_mutant_s5_s6_s7_s8_mov.csv'
Name = os.path.basename(os.path.splitext(csv_pred)[0])
tp = HolovizNapari.TruePositives(csv_gt, csv_pred, threshold = threshold)
MovieName.append(Name)
NetworkName.append('StaticSave29resf16')
CellName.append('Mature')
Accuracy.append(str('%.4f'%tp))

csv_pred = '/Users/aimachine/oneat_analysis/Penultimate/StaticSave29resf32/MatureP1LocationFlo_pupe2_mutant_s5_s6_s7_s8_mov.csv'
Name = os.path.basename(os.path.splitext(csv_pred)[0])
tp = HolovizNapari.TruePositives(csv_gt, csv_pred, threshold = threshold)
MovieName.append(Name)
NetworkName.append('StaticSave29resf32')
CellName.append('Mature')
Accuracy.append(str('%.4f'%tp))

csv_pred = '/Users/aimachine/oneat_analysis/Penultimate/StaticSave38resf16/MatureP1LocationFlo_pupe2_mutant_s5_s6_s7_s8_mov.csv'
Name = os.path.basename(os.path.splitext(csv_pred)[0])
tp = HolovizNapari.TruePositives(csv_gt, csv_pred, threshold = threshold)
MovieName.append(Name)
NetworkName.append('StaticSave38resf16')
CellName.append('Mature')
Accuracy.append(str('%.4f'%tp))


csv_gt = '/Users/aimachine/oneat_analysis/Penultimate/GT/divisionbin2V1/cellnetbin2/ONEATEventMovieMatureP1.csv'



csv_pred = '/Users/aimachine/oneat_analysis/Penultimate/StaticSave29resf16/MatureP1LocationEventMovie.csv'
Name = os.path.basename(os.path.splitext(csv_pred)[0])
tp = HolovizNapari.TruePositives(csv_gt, csv_pred, threshold = threshold)
MovieName.append(Name)
NetworkName.append('StaticSave29resf16')
CellName.append('Mature')
Accuracy.append(str('%.4f'%tp))

csv_pred = '/Users/aimachine/oneat_analysis/Penultimate/StaticSave29resf32/MatureP1LocationEventMovie.csv'
Name = os.path.basename(os.path.splitext(csv_pred)[0])
tp = HolovizNapari.TruePositives(csv_gt, csv_pred, threshold = threshold)
MovieName.append(Name)
NetworkName.append('StaticSave29resf32')
CellName.append('Mature')
Accuracy.append(str('%.4f'%tp))

csv_pred = '/Users/aimachine/oneat_analysis/Penultimate/StaticSave38resf16/MatureP1LocationEventMovie.csv'
Name = os.path.basename(os.path.splitext(csv_pred)[0])
tp = HolovizNapari.TruePositives(csv_gt, csv_pred, threshold = threshold)
MovieName.append(Name)
NetworkName.append('StaticSave38resf16')
CellName.append('Mature')
Accuracy.append(str('%.4f'%tp))


csv_gt = '/Users/aimachine/oneat_analysis/Penultimate/GT/divisionbin2V1/cellnetbin2/ONEATTimeLapseBIG1MatureP1.csv'



csv_pred = '/Users/aimachine/oneat_analysis/Penultimate/StaticSave29resf16/MatureP1LocationTimeLapseBIG1.csv'
Name = os.path.basename(os.path.splitext(csv_pred)[0])
tp = HolovizNapari.TruePositives(csv_gt, csv_pred, threshold = threshold)
MovieName.append(Name)
NetworkName.append('StaticSave29resf16')
CellName.append('Mature')
Accuracy.append(str('%.4f'%tp))

csv_pred = '/Users/aimachine/oneat_analysis/Penultimate/StaticSave29resf32/MatureP1LocationTimeLapseBIG1.csv'
Name = os.path.basename(os.path.splitext(csv_pred)[0])
tp = HolovizNapari.TruePositives(csv_gt, csv_pred, threshold = threshold)
MovieName.append(Name)
NetworkName.append('StaticSave29resf32')
CellName.append('Mature')
Accuracy.append(str('%.4f'%tp))

csv_pred = '/Users/aimachine/oneat_analysis/Penultimate/StaticSave38resf16/MatureP1LocationTimeLapseBIG1.csv'
Name = os.path.basename(os.path.splitext(csv_pred)[0])
tp = HolovizNapari.TruePositives(csv_gt, csv_pred, threshold = threshold)
MovieName.append(Name)
NetworkName.append('StaticSave38resf16')
CellName.append('Mature')
Accuracy.append(str('%.4f'%tp))


csv_gt = '/Users/aimachine/oneat_analysis/Penultimate/GT/divisionbin2V1/cellnetbin2/ONEATTimeLapseBIG5MatureP1.csv'



csv_pred = '/Users/aimachine/oneat_analysis/Penultimate/StaticSave29resf16/MatureP1LocationTimeLapseBIG5.csv'
Name = os.path.basename(os.path.splitext(csv_pred)[0])
tp = HolovizNapari.TruePositives(csv_gt, csv_pred, threshold = threshold)
MovieName.append(Name)
NetworkName.append('StaticSave29resf16')
CellName.append('Mature')
Accuracy.append(str('%.4f'%tp))

csv_pred = '/Users/aimachine/oneat_analysis/Penultimate/StaticSave29resf32/MatureP1LocationTimeLapseBIG5.csv'
Name = os.path.basename(os.path.splitext(csv_pred)[0])
tp = HolovizNapari.TruePositives(csv_gt, csv_pred, threshold = threshold)
MovieName.append(Name)
NetworkName.append('StaticSave29resf32')
CellName.append('Mature')
Accuracy.append(str('%.4f'%tp))

csv_pred = '/Users/aimachine/oneat_analysis/Penultimate/StaticSave38resf16/MatureP1LocationTimeLapseBIG5.csv'
Name = os.path.basename(os.path.splitext(csv_pred)[0])
tp = HolovizNapari.TruePositives(csv_gt, csv_pred, threshold = threshold)
MovieName.append(Name)
NetworkName.append('StaticSave38resf16')
CellName.append('Mature')
Accuracy.append(str('%.4f'%tp))



csv_gt = '/Users/aimachine/oneat_analysis/Penultimate/GT/divisionbin2V1/cellnetbin2/ONEATFlo_pupe1_s1_s2_s3_s4_movMatureP1.csv'



csv_pred = '/Users/aimachine/oneat_analysis/Penultimate/StaticSave29resf16/MatureP1LocationFlo_pupe1_s1_s2_s3_s4_mov.csv'
Name = os.path.basename(os.path.splitext(csv_pred)[0])
tp = HolovizNapari.TruePositives(csv_gt, csv_pred, threshold = threshold)
MovieName.append(Name)
NetworkName.append('StaticSave29resf16')
CellName.append('Mature')
Accuracy.append(str('%.4f'%tp))

csv_pred = '/Users/aimachine/oneat_analysis/Penultimate/StaticSave29resf32/MatureP1LocationFlo_pupe1_s1_s2_s3_s4_mov.csv'
Name = os.path.basename(os.path.splitext(csv_pred)[0])
tp = HolovizNapari.TruePositives(csv_gt, csv_pred, threshold = threshold)
MovieName.append(Name)
NetworkName.append('StaticSave29resf32')
CellName.append('Mature')
Accuracy.append(str('%.4f'%tp))

csv_pred = '/Users/aimachine/oneat_analysis/Penultimate/StaticSave38resf16/MatureP1LocationFlo_pupe1_s1_s2_s3_s4_mov.csv'
Name = os.path.basename(os.path.splitext(csv_pred)[0])
tp = HolovizNapari.TruePositives(csv_gt, csv_pred, threshold = threshold)
MovieName.append(Name)
NetworkName.append('StaticSave38resf16')
CellName.append('Mature')
Accuracy.append(str('%.4f'%tp))
df = pd.DataFrame(list(zip(MovieName,NetworkName,CellName,Accuracy)), index = None, 
                                                                      columns =['MovieName', 'NetworkName', 'CellType',  'Accuracy'])
                        
df.to_csv(resultsdir + '/' + 'MatureP1cellsAccuracy' +  '.csv')  
df
Accuracy = natsorted(Accuracy, reverse = True)

colors = np.random.rand(len(Accuracy))
plt.scatter(NetworkName, Accuracy,alpha=0.5, c = colors)


plt.show()
plt.savefig(resultsdir + '/' + 'MatureP1Accuracy' + '.png', dpi = 300)
df
# Out:
#                                             MovieName         NetworkName  \
# 0   MacroCheateLocationFlo_pupe2_mutant_s5_s6_s7_s...  StaticSave29resf16
# 1   MacroCheateLocationFlo_pupe2_mutant_s5_s6_s7_s...  StaticSave29resf32
# 2   MacroCheateLocationFlo_pupe2_mutant_s5_s6_s7_s...  StaticSave38resf16
# 3                       MacroCheateLocationEventMovie  StaticSave29resf16
# 4                       MacroCheateLocationEventMovie  StaticSave29resf32
# 5                       MacroCheateLocationEventMovie  StaticSave38resf16
# 6                    MacroCheateLocationTimeLapseBIG1  StaticSave29resf16
# 7                    MacroCheateLocationTimeLapseBIG1  StaticSave29resf32
# 8                    MacroCheateLocationTimeLapseBIG1  StaticSave38resf16
# 9                    MacroCheateLocationTimeLapseBIG5  StaticSave29resf16
# 10                   MacroCheateLocationTimeLapseBIG5  StaticSave29resf32
# 11                   MacroCheateLocationTimeLapseBIG5  StaticSave38resf16
# 12          MatureP1LocationFlo_pupe1_s1_s2_s3_s4_mov  StaticSave29resf16
# 13          MatureP1LocationFlo_pupe1_s1_s2_s3_s4_mov  StaticSave29resf32
# 14          MatureP1LocationFlo_pupe1_s1_s2_s3_s4_mov  StaticSave38resf16
# 15   MatureP1LocationFlo_pupe2_mutant_s5_s6_s7_s8_mov  StaticSave29resf16
# 16   MatureP1LocationFlo_pupe2_mutant_s5_s6_s7_s8_mov  StaticSave29resf32
# 17   MatureP1LocationFlo_pupe2_mutant_s5_s6_s7_s8_mov  StaticSave38resf16
# 18                         MatureP1LocationEventMovie  StaticSave29resf16
# 19                         MatureP1LocationEventMovie  StaticSave29resf32
# 20                         MatureP1LocationEventMovie  StaticSave38resf16
# 21                      MatureP1LocationTimeLapseBIG1  StaticSave29resf16
# 22                      MatureP1LocationTimeLapseBIG1  StaticSave29resf32
# 23                      MatureP1LocationTimeLapseBIG1  StaticSave38resf16
# 24                      MatureP1LocationTimeLapseBIG5  StaticSave29resf16
# 25                      MatureP1LocationTimeLapseBIG5  StaticSave29resf32
# 26                      MatureP1LocationTimeLapseBIG5  StaticSave38resf16
# 27          MatureP1LocationFlo_pupe1_s1_s2_s3_s4_mov  StaticSave29resf16
# 28          MatureP1LocationFlo_pupe1_s1_s2_s3_s4_mov  StaticSave29resf32
# 29          MatureP1LocationFlo_pupe1_s1_s2_s3_s4_mov  StaticSave38resf16
#
#        CellType  Accuracy
# 0   MacroCheate  100.0000
# 1   MacroCheate  100.0000
# 2   MacroCheate  100.0000
# 3   MacroCheate  100.0000
# 4   MacroCheate  100.0000
# 5   MacroCheate  100.0000
# 6   MacroCheate  100.0000
# 7   MacroCheate  100.0000
# 8   MacroCheate  100.0000
# 9   MacroCheate  100.0000
# 10  MacroCheate   91.9355
# 11  MacroCheate   82.6772
# 12       Mature  100.0000
# 13       Mature  100.0000
# 14       Mature    0.0000
# 15       Mature  100.0000
# 16       Mature  100.0000
# 17       Mature  100.0000
# 18       Mature  100.0000
# 19       Mature  100.0000
# 20       Mature  100.0000
# 21       Mature   99.4872
# 22       Mature   97.9487
# 23       Mature   97.4359
# 24       Mature  100.0000
# 25       Mature   97.3333
# 26       Mature   93.3333
# 27       Mature  100.0000
# 28       Mature  100.0000
# 29       Mature    0.0000

# %%
threshold = 20
MovieName = []
NetworkName = []
CellName = []
Accuracy = []

csv_gt = '/Users/aimachine/oneat_analysis/Penultimate/GT/divisionbin2V1/cellnetbin2/ONEATFlo_pupe2_mutant_s5_s6_s7_s8_movMacroCheate.csv'

csv_pred = '/Users/aimachine/oneat_analysis/Penultimate/StaticSave29resf16/MacroCheateLocationFlo_pupe2_mutant_s5_s6_s7_s8_mov.csv'
Name = os.path.basename(os.path.splitext(csv_pred)[0])
tp = HolovizNapari.TruePositives(csv_gt, csv_pred, threshold = threshold)
MovieName.append(Name)
NetworkName.append('StaticSave29resf16')
CellName.append('MacroCheate')
Accuracy.append(str('%.4f'%tp))

csv_pred = '/Users/aimachine/oneat_analysis/Penultimate/StaticSave29resf32/MacroCheateLocationFlo_pupe2_mutant_s5_s6_s7_s8_mov.csv'
Name = os.path.basename(os.path.splitext(csv_pred)[0])
tp = HolovizNapari.TruePositives(csv_gt, csv_pred, threshold = threshold)
MovieName.append(Name)
NetworkName.append('StaticSave29resf32')
CellName.append('MacroCheate')
Accuracy.append(str('%.4f'%tp))

csv_pred = '/Users/aimachine/oneat_analysis/Penultimate/StaticSave38resf16/MacroCheateLocationFlo_pupe2_mutant_s5_s6_s7_s8_mov.csv'
Name = os.path.basename(os.path.splitext(csv_pred)[0])
tp = HolovizNapari.TruePositives(csv_gt, csv_pred, threshold = threshold)
MovieName.append(Name)
NetworkName.append('StaticSave38resf16')
CellName.append('MacroCheate')
Accuracy.append(str('%.4f'%tp))


csv_gt = '/Users/aimachine/oneat_analysis/Penultimate/GT/divisionbin2V1/cellnetbin2/ONEATEventMovieMacroCheate.csv'

csv_pred = '/Users/aimachine/oneat_analysis/Penultimate/StaticSave29resf16/MacroCheateLocationEventMovie.csv'
Name = os.path.basename(os.path.splitext(csv_pred)[0])
tp = HolovizNapari.TruePositives(csv_gt, csv_pred, threshold = threshold)
MovieName.append(Name)
NetworkName.append('StaticSave29resf16')
CellName.append('MacroCheate')
Accuracy.append(str('%.4f'%tp))

csv_pred = '/Users/aimachine/oneat_analysis/Penultimate/StaticSave29resf32/MacroCheateLocationEventMovie.csv'
Name = os.path.basename(os.path.splitext(csv_pred)[0])
tp = HolovizNapari.TruePositives(csv_gt, csv_pred, threshold = threshold)
MovieName.append(Name)
NetworkName.append('StaticSave29resf32')
CellName.append('MacroCheate')
Accuracy.append(str('%.4f'%tp))

csv_pred = '/Users/aimachine/oneat_analysis/Penultimate/StaticSave38resf16/MacroCheateLocationEventMovie.csv'
Name = os.path.basename(os.path.splitext(csv_pred)[0])
tp = HolovizNapari.TruePositives(csv_gt, csv_pred, threshold = threshold)
MovieName.append(Name)
NetworkName.append('StaticSave38resf16')
CellName.append('MacroCheate')
Accuracy.append(str('%.4f'%tp))


csv_gt = '/Users/aimachine/oneat_analysis/Penultimate/GT/divisionbin2V1/cellnetbin2/ONEATTimeLapseBIG1MacroCheate.csv'

csv_pred = '/Users/aimachine/oneat_analysis/Penultimate/StaticSave29resf16/MacroCheateLocationTimeLapseBIG1.csv'
Name = os.path.basename(os.path.splitext(csv_pred)[0])
tp = HolovizNapari.TruePositives(csv_gt, csv_pred, threshold = threshold)
MovieName.append(Name)
NetworkName.append('StaticSave29resf16')
CellName.append('MacroCheate')
Accuracy.append(str('%.4f'%tp))

csv_pred = '/Users/aimachine/oneat_analysis/Penultimate/StaticSave29resf32/MacroCheateLocationTimeLapseBIG1.csv'
Name = os.path.basename(os.path.splitext(csv_pred)[0])
tp = HolovizNapari.TruePositives(csv_gt, csv_pred, threshold = threshold)
MovieName.append(Name)
NetworkName.append('StaticSave29resf32')
CellName.append('MacroCheate')
Accuracy.append(str('%.4f'%tp))

csv_pred = '/Users/aimachine/oneat_analysis/Penultimate/StaticSave38resf16/MacroCheateLocationTimeLapseBIG1.csv'
Name = os.path.basename(os.path.splitext(csv_pred)[0])
tp = HolovizNapari.TruePositives(csv_gt, csv_pred, threshold = threshold)
MovieName.append(Name)
NetworkName.append('StaticSave38resf16')
CellName.append('MacroCheate')
Accuracy.append(str('%.4f'%tp))


csv_gt = '/Users/aimachine/oneat_analysis/Penultimate/GT/divisionbin2V1/cellnetbin2/ONEATTimeLapseBIG5MacroCheate.csv'

csv_pred = '/Users/aimachine/oneat_analysis/Penultimate/StaticSave29resf16/MacroCheateLocationTimeLapseBIG5.csv'
Name = os.path.basename(os.path.splitext(csv_pred)[0])
tp = HolovizNapari.TruePositives(csv_gt, csv_pred, threshold = threshold)
MovieName.append(Name)
NetworkName.append('StaticSave29resf16')
CellName.append('MacroCheate')
Accuracy.append(str('%.4f'%tp))

csv_pred = '/Users/aimachine/oneat_analysis/Penultimate/StaticSave29resf32/MacroCheateLocationTimeLapseBIG5.csv'
Name = os.path.basename(os.path.splitext(csv_pred)[0])
tp = HolovizNapari.TruePositives(csv_gt, csv_pred, threshold = threshold)
MovieName.append(Name)
NetworkName.append('StaticSave29resf32')
CellName.append('MacroCheate')
Accuracy.append(str('%.4f'%tp))

csv_pred = '/Users/aimachine/oneat_analysis/Penultimate/StaticSave38resf16/MacroCheateLocationTimeLapseBIG5.csv'
Name = os.path.basename(os.path.splitext(csv_pred)[0])
tp = HolovizNapari.TruePositives(csv_gt, csv_pred, threshold = threshold)
MovieName.append(Name)
NetworkName.append('StaticSave38resf16')
CellName.append('MacroCheate')
Accuracy.append(str('%.4f'%tp))


df = pd.DataFrame(list(zip(MovieName,NetworkName,CellName,Accuracy)), index = None, 
                                                                      columns =['MovieName', 'NetworkName', 'CellType',  'Accuracy'])
                        
df.to_csv(resultsdir + '/' + 'MacroCheateAccuracy' +  '.csv')  
df

Accuracy = natsorted(Accuracy, reverse = True)

colors = np.random.rand(len(Accuracy))
plt.scatter(NetworkName, Accuracy, alpha=0.5, c = colors)

plt.show()
plt.savefig(resultsdir + '/' + 'MacroCheateAccuracy' + '.png', dpi = 300)
