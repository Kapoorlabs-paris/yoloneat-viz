# %%
import sys
import os
import glob
sys.path.append("../")
from yoloneatviz import NEATViz

# %gui qt

# %%
imagedir = '/Users/aimachine/oneatgolddust/Test/Raw/'
csvdir = '/Users/aimachine/oneatgolddust/Test/Raw/Saved29s4resf32/'
categories_json = '/Users/aimachine/oneatgolddust/Test/Raw/StaticCategories.json'
fileextension = '*tif'
Vizdetections = NEATViz(imagedir, csvdir,categories_json= categories_json, fileextension = fileextension)
# Out:
# 1
# []
# 97
# [[97, 376, 2002], [97, 960, 2170], [97, 1636, 2165], [97, 1644, 3080]]
# 98
# [[98, 571, 3250], [98, 1166, 3025], [98, 940, 1719]]
# 101
# [[101, 76, 3261], [101, 1157, 3035], [101, 349, 2920], [101, 98, 3577], [101, 373, 3393], [101, 964, 2174], [101, 1297, 2554], [101, 359, 2330]]
# 103
# [[103, 959, 2181], [103, 500, 2217], [103, 389, 1811], [103, 937, 1717], [103, 694, 1986]]
# 105
# [[105, 1240, 2231], [105, 1171, 3231], [105, 943, 1714], [105, 917, 1918], [105, 1263, 3370], [105, 963, 2182], [105, 350, 2339]]
# 109
# [[109, 507, 2576], [109, 171, 2473], [109, 566, 3288], [109, 544, 2075], [109, 663, 1781], [109, 963, 2196], [109, 349, 2336]]
# 110
# [[110, 519, 2793], [110, 475, 3105], [110, 120, 3614], [110, 806, 1720], [110, 1434, 2143], [110, 391, 1815], [110, 903, 2638]]
# 112
# ...
